# %%
##### RandomForestClassifier #######

# %%
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier ## use multi tree concept 
from sklearn.model_selection import train_test_split ## used to split train , test data
from sklearn.metrics import mean_absolute_error ## for evaluation --> using mean absolute error 
from sklearn.metrics import accuracy_score

# %%
data_train = pd.read_csv("./train.csv")
data_test1 = pd.read_csv("./test.csv")
data_test2 = pd.read_csv("./gender_submission.csv")

age_mean = 0
n = 0
for i in data_train.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1
age_mean = age_mean/(n)
#print(n)
#print(age_mean)

# print(np.mean(data_train.Age))

n=0
for i in data_train.Age:
    if np.isnan(i):
        data_train.Age[n] = age_mean
    n +=1 

## data_train.Age[np.where(np.isnan(data_train.Age), data_train.Age)[0]] = np.mean(data_train.Age)

n=0
for i in data_train.Sex:
    if i == "male":
        data_train.Sex[n] = 1
    else :
        data_train.Sex[n] = 0
    n +=1

n=0
for i in data_train.Embarked:
    if i == "Q":
        data_train.Embarked[n] = 1
    elif i == "C" :
        data_train.Embarked[n] = 0
    else : 
        data_train.Embarked[n] = 0.5
    n +=1

X_train = data_train.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
## print(X_train.loc[5,:])
Y_train = data_train.loc[:,['Survived']]


model = RandomForestClassifier(n_estimators=200)

model.fit(X_train,Y_train)

#print(data_train.Embarked)
# Out:
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\2857518641.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\2857518641.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\2857518641.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
age_mean = 0
n = 0
for i in data_test1.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1
age_mean = age_mean/(n)
#print(n)
#print(age_mean)

n=0
for i in data_test1.Age:
    if np.isnan(i):
        data_test1.Age[n] = age_mean
    n +=1

n=0
for i in data_test1.Sex:
    if i == "male":
        data_test1.Sex[n] = 1
    else :
        data_test1.Sex[n] = 0
    n +=1

n=0
for i in data_test1.Embarked:
    if i == "Q":
        data_test1.Embarked[n] = 1
    elif i == "C" :
        data_test1.Embarked[n] = 0
    else : 
        data_test1.Embarked[n] = 0.5
    n +=1

X_test = data_test1.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
#print(X_train.loc[5,:])
Y_test = data_test2.loc[:,['Survived']]

## print(X_test.loc[10,:])
# Out:
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\121875227.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test1.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\121875227.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test1.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\121875227.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
n=0
bug = 0
for i in X_test.Fare:
    if np.isnan(i):
        bug = n
        #print("bug in {}".format(n))
    else:
        pass
    n+=1

X_test.Fare[bug] = np.mean(X_test.Fare)
# Out:
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\282857233.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.Fare[bug] = np.mean(X_test.Fare)

# %%
## print(pd.DataFrame(Y_test))

# %%
y = model.predict(X_test)
print(accuracy_score(y, Y_test))
# Out:
# 0.7942583732057417

# %%
###  ------------------  naive-bayes  ------------------------  ###

# %%
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split ## used to split train , test data
from sklearn.metrics import mean_absolute_error ## for evaluation --> using mean absolute error 
from sklearn.metrics import accuracy_score




data_train = pd.read_csv("./train.csv")
data_test1 = pd.read_csv("./test.csv")
data_test2 = pd.read_csv("./gender_submission.csv")

age_mean = 0
n = 0
for i in data_train.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1

age_mean = age_mean/(n)
n=0
for i in data_train.Age:
    if np.isnan(i):
        data_train.Age[n] = age_mean
    n +=1 


n=0
for i in data_train.Sex:
    if i == "male":
        data_train.Sex[n] = 1
    else :
        data_train.Sex[n] = 0
    n +=1

n=0
for i in data_train.Embarked:
    if i == "Q":
        data_train.Embarked[n] = 1
    elif i == "C" :
        data_train.Embarked[n] = 0
    else : 
        data_train.Embarked[n] = 0.5
    n +=1

X_train = data_train.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

Y_train = data_train.loc[:,['Survived']]


model = GaussianNB()

model.fit(X_train,Y_train)

#-----------------------------------------------------------------------------------------------------

age_mean = 0
n = 0
for i in data_test1.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1
age_mean = age_mean/(n)

n=0
for i in data_test1.Age:
    if np.isnan(i):
        data_test1.Age[n] = age_mean
    n +=1

n=0
for i in data_test1.Sex:
    if i == "male":
        data_test1.Sex[n] = 1
    else :
        data_test1.Sex[n] = 0
    n +=1

n=0
for i in data_test1.Embarked:
    if i == "Q":
        data_test1.Embarked[n] = 1
    elif i == "C" :
        data_test1.Embarked[n] = 0
    else : 
        data_test1.Embarked[n] = 0.5
    n +=1

X_test = data_test1.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

Y_test = data_test2.loc[:,['Survived']]

n=0
bug = 0
for i in X_test.Fare:
    if np.isnan(i):
        bug = n
    else:
        pass
    n+=1
X_test.Fare[bug] = np.mean(X_test.Fare)

#------------------------------------------------------------------------------------------

y = model.predict(X_test)
print(" ACCURACY IS {} ".format(accuracy_score(y, Y_test)))


#----------------------------------------------------------------------------------------
# Out:
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\812534652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\812534652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\812534652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
### ---------------------------- KNN -------------------------------- ###

# %%
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split ## used to split train , test data
from sklearn.metrics import mean_absolute_error ## for evaluation --> using mean absolute error 
from sklearn.metrics import accuracy_score




data_train = pd.read_csv("./train.csv")
data_test1 = pd.read_csv("./test.csv")
data_test2 = pd.read_csv("./gender_submission.csv")


age_mean = 0
n = 0
for i in data_train.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1

age_mean = age_mean/(n)
n=0
for i in data_train.Age:
    if np.isnan(i):
        data_train.Age[n] = age_mean
    n +=1 


n=0
for i in data_train.Sex:
    if i == "male":
        data_train.Sex[n] = float(1)
    else :
        data_train.Sex[n] = float(0)
    n +=1

n=0
for i in data_train.Embarked:
    if i == "Q":
        data_train.Embarked[n] = 1
    elif i == "C" :
        data_train.Embarked[n] = 0
    else : 
        data_train.Embarked[n] = 0.5
    n +=1 

X_train = data_train.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

Y_train = data_train.loc[:,['Survived']]


#-----------------------------------------------------------------------------------------------------

age_mean = 0
n = 0
for i in data_test1.Age:
    if np.isnan(i):
        pass
    else :
        age_mean += i
        n += 1
age_mean = age_mean/(n)

n=0
for i in data_test1.Age:
    if np.isnan(i):
        data_test1.Age[n] = age_mean
    n +=1

n=0
for i in data_test1.Sex:
    if i == "male":
        data_test1.Sex[n] = (1)
    else :
        data_test1.Sex[n] = (0)
    n +=1

n=0
for i in data_test1.Embarked:
    if i == "Q":
        data_test1.Embarked[n] = 1
    elif i == "C" :
        data_test1.Embarked[n] = 0
    else : 
        data_test1.Embarked[n] = 0.5
    n +=1



X_test = data_test1.loc[:,['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

Y_test = data_test2.loc[:,['Survived']]



n=0
bug = 0
for i in X_test.Fare:
    if np.isnan(i):
        bug = n
    else:
        pass
    n+=1
X_test.Fare[bug] = np.mean(X_test.Fare) 

#------------------------------------------------------------------------------------------

model = KNeighborsClassifier()
model.fit(X_train,Y_train)

y = model.predict(X_test)
print(accuracy_score(y, Y_test))

#------------------------------------------------------------------------------------------
# Out:
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\1393269134.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\1393269134.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.Age[n] = age_mean
# C:\Users\Tec Narayan\AppData\Local\Temp\ipykernel_16732\1393269134.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
